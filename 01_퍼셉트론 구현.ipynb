# %% [markdown]
# 2학년 내용 복습

# %%
import numpy as np
import pandas as pd

# %%
import sklearn
print(sklearn.__version__)

# %%
# !pip install scikit-learn==1.0.2

# %%
from sklearn.datasets import load_boston
boston = load_boston()

print(boston)

# %%
print(boston.feature_names)

# %%
bostonDF = pd.DataFrame(boston.data, columns=boston.feature_names)
bostonDF['PRICE'] = boston.target

bostonDF.head()

# %%
# 스케일링: minmax

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(bostonDF[['RM', 'LSTAT']])
scaled_features

# %%
# Dense, Sequential, Adam

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

model = Sequential([
    Dense(1, input_shape=(2,), activation=None, kernel_initializer='zeros', bias_initializer='ones')
])

# 모델 환경설정
model.compile(optimizer=Adam(learning_rate=0.01), loss='mse', metrics=['mse'])

model.fit(scaled_features, bostonDF['PRICE'].values, epochs=1000)

# %%
predicted = model.predict(scaled_features)
bostonDF['RESULT'] = predicted
bostonDF.head()
# Out:
# 16/16 [==============================] - 0s 1ms/step
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  PRICE     RESULT
# 0     15.3  396.90   4.98   24.0  28.994671
# 1     17.8  396.90   9.14   21.6  25.521082
# 2     17.8  392.83   4.03   34.7  32.652954
# 3     18.7  394.63   2.94   33.4  32.429955
# 4     18.7  396.90   5.33   36.2  31.617924
